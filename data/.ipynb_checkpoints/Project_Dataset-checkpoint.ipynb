# %%
import numpy as np
import pandas as pd

# %%
read_rows = 2500
eeg_data = pd.read_csv("D:\Project\Datasets\dataset\EEG_data.csv",delimiter=',',nrows = read_rows)
eeg_data_info = pd.read_csv("D:\Project\Datasets\dataset\demographic_info.csv")

# %%
# Out:
#    SubjectID  VideoID  Attention  Mediation    Raw      Delta     Theta  \
# 0        0.0      0.0       56.0       43.0  278.0   301963.0   90612.0
# 1        0.0      0.0       40.0       35.0  -50.0    73787.0   28083.0
# 2        0.0      0.0       47.0       48.0  101.0   758353.0  383745.0
# 3        0.0      0.0       47.0       57.0   -5.0  2012240.0  129350.0
# 4        0.0      0.0       44.0       53.0   -8.0  1005145.0  354328.0
#
#      Alpha1   Alpha2    Beta1     Beta2   Gamma1   Gamma2  predefinedlabel  \
# 0   33735.0  23991.0  27946.0   45097.0  33228.0   8293.0              0.0
# 1    1439.0   2240.0   2746.0    3687.0   5293.0   2740.0              0.0
# 2  201999.0  62107.0  36293.0  130536.0  57243.0  25354.0              0.0
# 3   61236.0  17084.0  11488.0   62462.0  49960.0  33932.0              0.0
# 4   37102.0  88881.0  45307.0   99603.0  44790.0  29749.0              0.0
#
#    user-definedlabeln
# 0                 0.0
# 1                 0.0
# ...

# %%
eeg_data.head()
# Out:
#    SubjectID  VideoID  Attention  Mediation    Raw      Delta     Theta  \
# 0        0.0      0.0       56.0       43.0  278.0   301963.0   90612.0
# 1        0.0      0.0       40.0       35.0  -50.0    73787.0   28083.0
# 2        0.0      0.0       47.0       48.0  101.0   758353.0  383745.0
# 3        0.0      0.0       47.0       57.0   -5.0  2012240.0  129350.0
# 4        0.0      0.0       44.0       53.0   -8.0  1005145.0  354328.0
#
#      Alpha1   Alpha2    Beta1     Beta2   Gamma1   Gamma2  predefinedlabel  \
# 0   33735.0  23991.0  27946.0   45097.0  33228.0   8293.0              0.0
# 1    1439.0   2240.0   2746.0    3687.0   5293.0   2740.0              0.0
# 2  201999.0  62107.0  36293.0  130536.0  57243.0  25354.0              0.0
# 3   61236.0  17084.0  11488.0   62462.0  49960.0  33932.0              0.0
# 4   37102.0  88881.0  45307.0   99603.0  44790.0  29749.0              0.0
#
#    user-definedlabeln
# 0                 0.0
# 1                 0.0
# ...

# %%
eeg_data.shape
# Out:
# (2500, 15)

# %%
# Out:
# (12811, 15)

# %%
dataset = pd.read_csv("D:\Project\Datasets\dataset\eeg_dataset.csv")

# %%
dataset
# Out:
#       SubjectID  VideoID  Attention  Mediation    Raw      Delta     Theta  \
# 0           0.0      0.0       56.0       43.0  278.0   301963.0   90612.0
# 1           0.0      0.0       40.0       35.0  -50.0    73787.0   28083.0
# 2           0.0      0.0       47.0       48.0  101.0   758353.0  383745.0
# 3           0.0      0.0       47.0       57.0   -5.0  2012240.0  129350.0
# 4           0.0      0.0       44.0       53.0   -8.0  1005145.0  354328.0
# ...         ...      ...        ...        ...    ...        ...       ...
# 2495        1.0      9.0       48.0       66.0   10.0     6984.0   49114.0
# 2496        1.0      9.0       30.0       64.0   85.0  1808444.0  278219.0
# 2497        1.0      9.0       38.0       57.0   -8.0    23559.0   34621.0
# 2498        1.0      9.0       48.0       57.0   87.0   146187.0   47222.0
# 2499        1.0      9.0       60.0       60.0    9.0    42209.0   43895.0
#
# ...
