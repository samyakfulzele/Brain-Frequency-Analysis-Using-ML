# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import losses

# %%
eeg_data_info = pd.read_csv("D:\Project Model\Datasets\dataset\eda_data_info.csv")

# %%
min_value = eeg_data_info['MeanTheta'].min()
max_value = eeg_data_info['MeanTheta'].max()
eeg_data_info['MeanNormalized'] = (eeg_data_info['MeanTheta'] - min_value) / (max_value - min_value)
eeg_data_info['MeanNormalized'] = eeg_data_info['MeanNormalized'].round(2)
eeg_data_info['Confusion_score'] = eeg_data_info['MeanNormalized'].round(1)

# %%
def categorized(value):
    if value <= 0.33:
        return 0
    elif value > 0.33 and value <= 0.66:
        return 1
    else:
        return 2
eeg_data_info['Category'] = eeg_data_info['MeanNormalized'].apply(categorized)

# %%
eeg_data_info
# Out:
#        SubjectID  Age  Ethnicity  Gender  VideoID  Attention  Mediation  \
# 0              0   25          0       1      0.0       56.0       43.0
# 1              0   25          0       1      0.0       40.0       35.0
# 2              0   25          0       1      0.0       47.0       48.0
# 3              0   25          0       1      0.0       47.0       57.0
# 4              0   25          0       1      0.0       44.0       53.0
# ...          ...  ...        ...     ...      ...        ...        ...
# 11531          9   24          0       0      9.0       64.0       38.0
# 11532          9   24          0       0      9.0       61.0       35.0
# 11533          9   24          0       0      9.0       60.0       29.0
# 11534          9   24          0       0      9.0       60.0       29.0
# 11535          9   24          0       0      9.0       64.0       29.0
#
#          Raw      Delta      Theta  ...     Beta2   Gamma1   Gamma2  \
# 0      278.0   301963.0    90612.0  ...   45097.0  33228.0   8293.0
# 1      -50.0    73787.0    28083.0  ...    3687.0   5293.0   2740.0
# 2      101.0   758353.0   383745.0  ...  130536.0  57243.0  25354.0
# 3       -5.0  2012240.0   129350.0  ...   62462.0  49960.0  33932.0
# 4       -8.0  1005145.0   354328.0  ...   99603.0  44790.0  29749.0
# ...      ...        ...        ...  ...       ...      ...      ...
# 11531  -39.0   127574.0     9951.0  ...   39728.0   2598.0    960.0
# 11532 -275.0   323061.0   797464.0  ...  571280.0  36574.0  10010.0
# 11533 -426.0   680989.0   154296.0  ...   26975.0  20427.0   2024.0
# 11534  -84.0   366269.0    27346.0  ...    3283.0  12323.0   1764.0
# 11535  -49.0  1164555.0  1184366.0  ...  445383.0  22133.0   4482.0
#
#        predefinedlabel  user-definedlabeln   Sample      MeanTheta  \
# 0                  0.0                 0.0      0.5  124965.590278
# 1                  0.0                 0.0      1.5  124965.590278
# 2                  0.0                 0.0      2.5  124965.590278
# 3                  0.0                 0.0      3.5  124965.590278
# 4                  0.0                 0.0      4.5  124965.590278
# ...                ...                 ...      ...            ...
# 11531              1.0                 0.0  12806.5  162498.680328
# 11532              1.0                 0.0  12807.5  162498.680328
# 11533              1.0                 0.0  12808.5  162498.680328
# 11534              1.0                 0.0  12809.5  162498.680328
# 11535              1.0                 0.0  12810.5  162498.680328
#
#        MeanNormalized  Confusion_score  Category
# 0                0.33              0.3         0
# 1                0.33              0.3         0
# 2                0.33              0.3         0
# 3                0.33              0.3         0
# 4                0.33              0.3         0
# ...               ...              ...       ...
# 11531            0.43              0.4         1
# 11532            0.43              0.4         1
# 11533            0.43              0.4         1
# 11534            0.43              0.4         1
# 11535            0.43              0.4         1
#
# [11536 rows x 23 columns]

# %%
columns_to_keep = ['MeanNormalized','Delta','Theta']
X = eeg_data_info.drop(eeg_data_info.columns.difference(columns_to_keep), axis=1)
y = eeg_data_info['Category']

# %%
print(X,y)
# Out:
#            Delta      Theta  MeanNormalized
# 0       301963.0    90612.0            0.33
# 1        73787.0    28083.0            0.33
# 2       758353.0   383745.0            0.33
# 3      2012240.0   129350.0            0.33
# 4      1005145.0   354328.0            0.33
# ...          ...        ...             ...
# 11531   127574.0     9951.0            0.43
# 11532   323061.0   797464.0            0.43
# 11533   680989.0   154296.0            0.43
# 11534   366269.0    27346.0            0.43
# 11535  1164555.0  1184366.0            0.43
#
# [11536 rows x 3 columns] 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 11531    1
# 11532    1
# 11533    1
# 11534    1
# 11535    1
# Name: Category, Length: 11536, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Sample', y='MeanNormalized', hue='Category', data=eeg_data_info, palette='dark')

plt.title('Sample vs MeanNormalized')
plt.xlabel('Sample')
plt.ylabel('MeanNormalized')
plt.legend(title='Confusion Score')
plt.show()

# %%
print(X.shape)
print(y.shape)
# Out:
# (11536, 3)
# (11536,)

# %%
X_train, X_test, y_train, y_test = train_test_split(StandardScaler().fit_transform(X), y, test_size=0.3, random_state=42)

print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (8075, 3) (8075,)
# (3461, 3) (3461,)

# %%
model = Sequential()
model.add(Dense(32, input_shape=(3,), activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(3, activation='softmax'))

model.compile(optimizer='adam', loss=losses.SparseCategoricalCrossentropy(), metrics=['accuracy']) 

history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Evaluate the model on the test data
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test loss: {loss*100:.4f}, Test accuracy: {accuracy*100:.4f}")
# Out:
# Epoch 1/50
# C:\Users\Samyak Fulzele\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7305 - loss: 0.6902 - val_accuracy: 0.9526 - val_loss: 0.1363
# Epoch 2/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - accuracy: 0.9625 - loss: 0.1164 - val_accuracy: 0.9882 - val_loss: 0.0741
# Epoch 3/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - accuracy: 0.9822 - loss: 0.0683 - val_accuracy: 0.9931 - val_loss: 0.0481
# Epoch 4/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - accuracy: 0.9900 - loss: 0.0495 - val_accuracy: 0.9965 - val_loss: 0.0437
# Epoch 5/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9922 - loss: 0.0358 - val_accuracy: 0.9994 - val_loss: 0.0265
# Epoch 6/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9944 - loss: 0.0270 - val_accuracy: 0.9980 - val_loss: 0.0218
# Epoch 7/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - accuracy: 0.9983 - loss: 0.0214 - val_accuracy: 0.9948 - val_loss: 0.0237
# Epoch 8/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - accuracy: 0.9976 - loss: 0.0181 - val_accuracy: 0.9983 - val_loss: 0.0134
# Epoch 9/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9968 - loss: 0.0172 - val_accuracy: 0.9983 - val_loss: 0.0121
# Epoch 10/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9988 - loss: 0.0114 - val_accuracy: 0.9997 - val_loss: 0.0087
# Epoch 11/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - accuracy: 0.9994 - loss: 0.0093 - val_accuracy: 0.9936 - val_loss: 0.0331
# Epoch 12/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.9947 - loss: 0.0166 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 13/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9996 - loss: 0.0057 - val_accuracy: 0.9983 - val_loss: 0.0079
# Epoch 14/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9969 - loss: 0.0119 - val_accuracy: 0.9997 - val_loss: 0.0055
# Epoch 15/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - accuracy: 0.9975 - loss: 0.0094 - val_accuracy: 0.9991 - val_loss: 0.0058
# Epoch 16/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9994 - loss: 0.0039 - val_accuracy: 0.9997 - val_loss: 0.0032
# Epoch 17/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - accuracy: 0.9994 - loss: 0.0038 - val_accuracy: 0.9974 - val_loss: 0.0063
# Epoch 18/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9994 - loss: 0.0036 - val_accuracy: 0.9965 - val_loss: 0.0098
# Epoch 19/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - accuracy: 0.9983 - loss: 0.0078 - val_accuracy: 0.9994 - val_loss: 0.0029
# Epoch 20/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - accuracy: 0.9996 - loss: 0.0022 - val_accuracy: 0.9977 - val_loss: 0.0091
# Epoch 21/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9965 - loss: 0.0137 - val_accuracy: 0.9997 - val_loss: 0.0025
# Epoch 22/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 23/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9965 - val_loss: 0.0115
# Epoch 24/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - accuracy: 0.9969 - loss: 0.0096 - val_accuracy: 0.9962 - val_loss: 0.0209
# Epoch 25/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9946 - loss: 0.0185 - val_accuracy: 0.9997 - val_loss: 0.0023
# Epoch 26/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9998 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 7.5845e-04
# Epoch 27/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 7.0070e-04 - val_accuracy: 1.0000 - val_loss: 6.6549e-04
# Epoch 28/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 5.8796e-04 - val_accuracy: 0.9997 - val_loss: 0.0012
# Epoch 29/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0112 - val_accuracy: 0.9994 - val_loss: 0.0017
# Epoch 30/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 5.7322e-04
# Epoch 31/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 4.4287e-04 - val_accuracy: 1.0000 - val_loss: 5.0920e-04
# Epoch 32/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.7016e-04 - val_accuracy: 1.0000 - val_loss: 5.0735e-04
# Epoch 33/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.4304e-04 - val_accuracy: 1.0000 - val_loss: 4.4127e-04
# Epoch 34/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.6593e-04 - val_accuracy: 1.0000 - val_loss: 3.5039e-04
# Epoch 35/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.6177e-04 - val_accuracy: 1.0000 - val_loss: 3.2751e-04
# Epoch 36/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.1433e-04 - val_accuracy: 1.0000 - val_loss: 3.6989e-04
# Epoch 37/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.0530e-04 - val_accuracy: 0.9997 - val_loss: 5.5526e-04
# Epoch 38/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 1.9573e-04 - val_accuracy: 0.9997 - val_loss: 9.2658e-04
# Epoch 39/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0155 - val_accuracy: 0.9954 - val_loss: 0.0171
# Epoch 40/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9973 - loss: 0.0077 - val_accuracy: 0.9991 - val_loss: 0.0032
# Epoch 41/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 8.8826e-04 - val_accuracy: 1.0000 - val_loss: 6.5958e-04
# Epoch 42/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 4.6930e-04 - val_accuracy: 0.9997 - val_loss: 6.5453e-04
# Epoch 43/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 3.6970e-04 - val_accuracy: 1.0000 - val_loss: 4.1816e-04
# Epoch 44/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.9857e-04 - val_accuracy: 0.9997 - val_loss: 5.2646e-04
# Epoch 45/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.3539e-04 - val_accuracy: 1.0000 - val_loss: 4.0866e-04
# Epoch 46/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 2.2119e-04 - val_accuracy: 0.9997 - val_loss: 5.1183e-04
# Epoch 47/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 1.7379e-04 - val_accuracy: 1.0000 - val_loss: 3.2262e-04
# Epoch 48/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 1.5178e-04 - val_accuracy: 0.9997 - val_loss: 4.6836e-04
# Epoch 49/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 1.5602e-04 - val_accuracy: 0.9997 - val_loss: 3.5191e-04
# Epoch 50/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 1.0000 - loss: 1.1945e-04 - val_accuracy: 0.9997 - val_loss: 5.7140e-04
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - accuracy: 0.9999 - loss: 3.1109e-04
# Test loss: 0.0571, Test accuracy: 99.9711
